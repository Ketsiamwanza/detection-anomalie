# %%
from scapy.all import sniff
import pandas as pd
from sklearn.ensemble import IsolationForest
import matplotlib.pyplot as plt

# %%
# Liste pour stocker les paquets capturés
captured_packets = []


def packet_callback(packet):
    # Afficher le paquet capturé
    packet.show()

    # Extraire les informations pertinentes du paquet
    packet_info = {
        'timestamp': packet.time,
        'source': packet[0][1].src,
        'destination': packet[0][1].dst,
        'protocol': packet[0][1].proto,
        'length': len(packet)
    }
    captured_packets.append(packet_info)

# Capture des paquets
print("Capture de paquets en cours... (Appuyez sur Ctrl+C pour arrêter)")
try:
    sniff(prn=packet_callback, store=0)  # store=0 évite de stocker les paquets en mémoire
except KeyboardInterrupt:
    print("Capture interrompue.")
# Out:
# Capture de paquets en cours... (Appuyez sur Ctrl+C pour arrêter)
# ###[ Ethernet ]###
#   dst       = 0a:c5:e1:a5:0f:65
#   src       = c4:9d:ed:1c:1d:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 41
#      id        = 16970
#      flags     = DF
#      frag      = 0
#      ttl       = 128
#      proto     = tcp
#      chksum    = 0xfc61
#      src       = 192.168.43.65
#      dst       = 74.125.133.188
#      \options   \
# ###[ TCP ]###
#         sport     = 49876
#         dport     = 5228
#         seq       = 858375492
#         ack       = 4068047672
#         dataofs   = 5
#         reserved  = 0
#         flags     = A
#         window    = 514
#         chksum    = 0xb44d
#         urgptr    = 0
#         options   = []
# ###[ Raw ]###
#            load      = b'\x00'
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x1c
#      len       = 52
#      id        = 17835
#      flags     = DF
#      frag      = 0
#      ttl       = 124
#      proto     = tcp
#      chksum    = 0xfcd9
#      src       = 74.125.133.188
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = 5228
#         dport     = 49876
#         seq       = 4068047672
#         ack       = 858375493
#         dataofs   = 8
#         reserved  = 0
#         flags     = A
#         window    = 420
#         chksum    = 0x8db7
#         urgptr    = 0
#         options   = [('NOP', None), ('NOP', None), ('SAck', (858375492, 858375493))]
#
# ###[ Ethernet ]###
#   dst       = 0a:c5:e1:a5:0f:65
#   src       = c4:9d:ed:1c:1d:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 40
#      id        = 3030
#      flags     = DF
#      frag      = 0
#      ttl       = 128
#      proto     = tcp
#      chksum    = 0x5e14
#      src       = 192.168.43.65
#      dst       = 2.16.162.236
#      \options   \
# ###[ TCP ]###
#         sport     = 50461
#         dport     = https
#         seq       = 502399064
#         ack       = 2057813954
#         dataofs   = 5
#         reserved  = 0
#         flags     = FA
#         window    = 509
#         chksum    = 0xfd63
#         urgptr    = 0
#         options   = []
#
# ###[ Ethernet ]###
#   dst       = 0a:c5:e1:a5:0f:65
#   src       = c4:9d:ed:1c:1d:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 40
#      id        = 3031
#      flags     = DF
#      frag      = 0
#      ttl       = 128
#      proto     = tcp
#      chksum    = 0x5e13
#      src       = 192.168.43.65
#      dst       = 2.16.162.236
#      \options   \
# ###[ TCP ]###
#         sport     = 50464
#         dport     = https
#         seq       = 1229813195
#         ack       = 3567501523
#         dataofs   = 5
#         reserved  = 0
#         flags     = FA
#         window    = 513
#         chksum    = 0x181
#         urgptr    = 0
#         options   = []
#
# ###[ Ethernet ]###
#   dst       = 0a:c5:e1:a5:0f:65
#   src       = c4:9d:ed:1c:1d:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 40
#      id        = 3032
#      flags     = DF
#      frag      = 0
#      ttl       = 128
#      proto     = tcp
#      chksum    = 0x5e12
#      src       = 192.168.43.65
#      dst       = 2.16.162.236
#      \options   \
# ###[ TCP ]###
#         sport     = 50462
#         dport     = https
#         seq       = 3745326658
#         ack       = 1088186188
#         dataofs   = 5
#         reserved  = 0
#         flags     = FA
#         window    = 513
#         chksum    = 0xa86a
#         urgptr    = 0
#         options   = []
#
# ###[ Ethernet ]###
#   dst       = 0a:c5:e1:a5:0f:65
#   src       = c4:9d:ed:1c:1d:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 40
#      id        = 3033
#      flags     = DF
#      frag      = 0
#      ttl       = 128
#      proto     = tcp
#      chksum    = 0x5e11
#      src       = 192.168.43.65
#      dst       = 2.16.162.236
#      \options   \
# ###[ TCP ]###
#         sport     = 50463
#         dport     = https
#         seq       = 2277363103
#         ack       = 3798815154
#         dataofs   = 5
#         reserved  = 0
#         flags     = FA
#         window    = 513
#         chksum    = 0xcc94
#         urgptr    = 0
#         options   = []
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x1c
#      len       = 40
#      id        = 8894
#      flags     = DF
#      frag      = 0
#      ttl       = 124
#      proto     = tcp
#      chksum    = 0x4b10
#      src       = 2.16.162.236
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = https
#         dport     = 50464
#         seq       = 3567501523
#         ack       = 1229813196
#         dataofs   = 5
#         reserved  = 0
#         flags     = A
#         window    = 748
#         chksum    = 0x96
#         urgptr    = 0
#         options   = []
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x1c
#      len       = 40
#      id        = 10821
#      flags     = DF
#      frag      = 0
#      ttl       = 124
#      proto     = tcp
#      chksum    = 0x4389
#      src       = 2.16.162.236
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = https
#         dport     = 50463
#         seq       = 3798815154
#         ack       = 2277363104
#         dataofs   = 5
#         reserved  = 0
#         flags     = A
#         window    = 748
#         chksum    = 0xcba9
#         urgptr    = 0
#         options   = []
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x1c
#      len       = 71
#      id        = 41383
#      flags     = DF
#      frag      = 0
#      ttl       = 51
#      proto     = tcp
#      chksum    = 0x1508
#      src       = 2.16.162.236
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = https
#         dport     = 50461
#         seq       = 2057813954
#         ack       = 502399065
#         dataofs   = 5
#         reserved  = 0
#         flags     = PA
#         window    = 501
#         chksum    = 0x6149
#         urgptr    = 0
#         options   = []
# ###[ Raw ]###
#            load      = b'\x15\x03\x03\x00\x1a\xf4\x85\xcePz-\xd2h"\x05O\xbem\x8b@\xe0[\xfflX1y,3\xa2\xc9'
#
# ###[ Ethernet ]###
#   dst       = 0a:c5:e1:a5:0f:65
#   src       = c4:9d:ed:1c:1d:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 40
#      id        = 3034
#      flags     = DF
#      frag      = 0
#      ttl       = 128
#      proto     = tcp
#      chksum    = 0x5e10
#      src       = 192.168.43.65
#      dst       = 2.16.162.236
#      \options   \
# ###[ TCP ]###
#         sport     = 50461
#         dport     = https
#         seq       = 502399065
#         ack       = 2057813985
#         dataofs   = 5
#         reserved  = 0
#         flags     = RA
#         window    = 0
#         chksum    = 0xff3d
#         urgptr    = 0
#         options   = []
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x1c
#      len       = 40
#      id        = 41384
#      flags     = DF
#      frag      = 0
#      ttl       = 51
#      proto     = tcp
#      chksum    = 0x1526
#      src       = 2.16.162.236
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = https
#         dport     = 50461
#         seq       = 2057813985
#         ack       = 502399065
#         dataofs   = 5
#         reserved  = 0
#         flags     = FA
#         window    = 501
#         chksum    = 0xfd4b
#         urgptr    = 0
#         options   = []
#
# ###[ Ethernet ]###
#   dst       = 0a:c5:e1:a5:0f:65
#   src       = c4:9d:ed:1c:1d:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 40
#      id        = 3035
#      flags     = DF
#      frag      = 0
#      ttl       = 128
#      proto     = tcp
#      chksum    = 0x5e0f
#      src       = 192.168.43.65
#      dst       = 2.16.162.236
#      \options   \
# ###[ TCP ]###
#         sport     = 50461
#         dport     = https
#         seq       = 502399065
#         ack       = 502399065
#         dataofs   = 5
#         reserved  = 0
#         flags     = R
#         window    = 0
#         chksum    = 0x1b8c
#         urgptr    = 0
#         options   = []
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x1c
#      len       = 71
#      id        = 8895
#      flags     = DF
#      frag      = 0
#      ttl       = 124
#      proto     = tcp
#      chksum    = 0x4af0
#      src       = 2.16.162.236
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = https
#         dport     = 50464
#         seq       = 3567501523
#         ack       = 1229813196
#         dataofs   = 5
#         reserved  = 0
#         flags     = PA
#         window    = 748
#         chksum    = 0x3f71
#         urgptr    = 0
#         options   = []
# ###[ Raw ]###
#            load      = b'\x15\x03\x03\x00\x1a\ns}\x07N\xfd\x1c\xf2\xd6\r3[\xf6J\xc7\x08\xcbT\xc6(\xa9;r\xa1\x93\r'
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x1c
#      len       = 40
#      id        = 8896
#      flags     = DF
#      frag      = 0
#      ttl       = 124
#      proto     = tcp
#      chksum    = 0x4b0e
#      src       = 2.16.162.236
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = https
#         dport     = 50464
#         seq       = 3567501554
#         ack       = 1229813196
#         dataofs   = 5
#         reserved  = 0
#         flags     = FA
#         window    = 748
#         chksum    = 0x76
#         urgptr    = 0
#         options   = []
#
# ###[ Ethernet ]###
#   dst       = 0a:c5:e1:a5:0f:65
#   src       = c4:9d:ed:1c:1d:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 40
#      id        = 3036
#      flags     = DF
#      frag      = 0
#      ttl       = 128
#      proto     = tcp
#      chksum    = 0x5e0e
#      src       = 192.168.43.65
#      dst       = 2.16.162.236
#      \options   \
# ###[ TCP ]###
#         sport     = 50464
#         dport     = https
#         seq       = 1229813196
#         ack       = 3567501554
#         dataofs   = 5
#         reserved  = 0
#         flags     = RA
#         window    = 0
#         chksum    = 0x35f
#         urgptr    = 0
#         options   = []
#
# ###[ Ethernet ]###
#   dst       = 0a:c5:e1:a5:0f:65
#   src       = c4:9d:ed:1c:1d:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 40
#      id        = 3037
#      flags     = DF
#      frag      = 0
#      ttl       = 128
#      proto     = tcp
#      chksum    = 0x5e0d
#      src       = 192.168.43.65
#      dst       = 2.16.162.236
#      \options   \
# ###[ TCP ]###
#         sport     = 50464
#         dport     = https
#         seq       = 1229813196
#         ack       = 1229813196
#         dataofs   = 5
#         reserved  = 0
#         flags     = R
#         window    = 0
#         chksum    = 0xd9eb
#         urgptr    = 0
#         options   = []
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x1c
#      len       = 71
#      id        = 5353
#      flags     = DF
#      frag      = 0
#      ttl       = 51
#      proto     = tcp
#      chksum    = 0xa1c6
#      src       = 2.16.162.236
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = https
#         dport     = 50462
#         seq       = 1088186188
#         ack       = 3745326659
#         dataofs   = 5
#         reserved  = 0
#         flags     = PA
#         window    = 501
#         chksum    = 0xf73e
#         urgptr    = 0
#         options   = []
# ###[ Raw ]###
#            load      = b'\x15\x03\x03\x00\x1a"\xa9\xe1$\x90\x08\xfd\xab\xc8Q\xd1F\xc9\xb4\xa1x\x84\xfb\xa7\xf6\x16\xc6\xe1\x9dQ\xe0'
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x1c
#      len       = 40
#      id        = 5354
#      flags     = DF
#      frag      = 0
#      ttl       = 51
#      proto     = tcp
#      chksum    = 0xa1e4
#      src       = 2.16.162.236
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = https
#         dport     = 50462
#         seq       = 1088186219
#         ack       = 3745326659
#         dataofs   = 5
#         reserved  = 0
#         flags     = FA
#         window    = 501
#         chksum    = 0xa856
#         urgptr    = 0
#         options   = []
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x1c
#      len       = 71
#      id        = 10822
#      flags     = DF
#      frag      = 0
#      ttl       = 124
#      proto     = tcp
#      chksum    = 0x4369
#      src       = 2.16.162.236
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = https
#         dport     = 50463
#         seq       = 3798815154
#         ack       = 2277363104
#         dataofs   = 5
#         reserved  = 0
#         flags     = PA
#         window    = 748
#         chksum    = 0x2f7a
#         urgptr    = 0
#         options   = []
# ###[ Raw ]###
#            load      = b"\x15\x03\x03\x00\x1a\n)\x81G=[\xbb@j~9\xbf\xab)M\xa7\xfbE\x8e5\xef'\x058fs"
#
# ###[ Ethernet ]###
#   dst       = 0a:c5:e1:a5:0f:65
#   src       = c4:9d:ed:1c:1d:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 40
#      id        = 3038
#      flags     = DF
#      frag      = 0
#      ttl       = 128
#      proto     = tcp
#      chksum    = 0x5e0c
#      src       = 192.168.43.65
#      dst       = 2.16.162.236
#      \options   \
# ###[ TCP ]###
#         sport     = 50462
#         dport     = https
#         seq       = 3745326659
#         ack       = 1088186219
#         dataofs   = 5
#         reserved  = 0
#         flags     = RA
#         window    = 0
#         chksum    = 0xaa48
#         urgptr    = 0
#         options   = []
#
# ###[ Ethernet ]###
#   dst       = 0a:c5:e1:a5:0f:65
#   src       = c4:9d:ed:1c:1d:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 40
#      id        = 3039
#      flags     = DF
#      frag      = 0
#      ttl       = 128
#      proto     = tcp
#      chksum    = 0x5e0b
#      src       = 192.168.43.65
#      dst       = 2.16.162.236
#      \options   \
# ###[ TCP ]###
#         sport     = 50462
#         dport     = https
#         seq       = 3745326659
#         ack       = 3745326659
#         dataofs   = 5
#         reserved  = 0
#         flags     = R
#         window    = 0
#         chksum    = 0x4d1f
#         urgptr    = 0
#         options   = []
#
# ###[ Ethernet ]###
#   dst       = 0a:c5:e1:a5:0f:65
#   src       = c4:9d:ed:1c:1d:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 40
#      id        = 3040
#      flags     = DF
#      frag      = 0
#      ttl       = 128
#      proto     = tcp
#      chksum    = 0x5e0a
#      src       = 192.168.43.65
#      dst       = 2.16.162.236
#      \options   \
# ###[ TCP ]###
#         sport     = 50463
#         dport     = https
#         seq       = 2277363104
#         ack       = 3798815185
#         dataofs   = 5
#         reserved  = 0
#         flags     = RA
#         window    = 0
#         chksum    = 0xce72
#         urgptr    = 0
#         options   = []
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x1c
#      len       = 40
#      id        = 10823
#      flags     = DF
#      frag      = 0
#      ttl       = 124
#      proto     = tcp
#      chksum    = 0x4387
#      src       = 2.16.162.236
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = https
#         dport     = 50463
#         seq       = 3798815185
#         ack       = 2277363104
#         dataofs   = 5
#         reserved  = 0
#         flags     = FA
#         window    = 748
#         chksum    = 0xcb89
#         urgptr    = 0
#         options   = []
#
# ###[ Ethernet ]###
#   dst       = 0a:c5:e1:a5:0f:65
#   src       = c4:9d:ed:1c:1d:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 40
#      id        = 3041
#      flags     = DF
#      frag      = 0
#      ttl       = 128
#      proto     = tcp
#      chksum    = 0x5e09
#      src       = 192.168.43.65
#      dst       = 2.16.162.236
#      \options   \
# ###[ TCP ]###
#         sport     = 50463
#         dport     = https
#         seq       = 2277363104
#         ack       = 2277363104
#         dataofs   = 5
#         reserved  = 0
#         flags     = R
#         window    = 0
#         chksum    = 0xad63
#         urgptr    = 0
#         options   = []
#
# ###[ Ethernet ]###
#   dst       = 0a:c5:e1:a5:0f:65
#   src       = c4:9d:ed:1c:1d:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 91
#      id        = 22659
#      flags     = DF
#      frag      = 0
#      ttl       = 128
#      proto     = tcp
#      chksum    = 0x8ca6
#      src       = 192.168.43.65
#      dst       = 162.159.134.234
#      \options   \
# ###[ TCP ]###
#         sport     = 49772
#         dport     = https
#         seq       = 1190622556
#         ack       = 1040526503
#         dataofs   = 5
#         reserved  = 0
#         flags     = PA
#         window    = 509
#         chksum    = 0x4efa
#         urgptr    = 0
#         options   = []
# ###[ Raw ]###
#            load      = b'\x17\x03\x03\x00.\x94\x04TU\xdb\xb4\xcb!(\xe8\x15%\xdb\xd0\xfd\x8f\xda\xa8\xf0]\x89\xb2\xdc(\xd1y\xfa\x1d8\xf5\xbd\xa2N\xc0\xf5\xa8\x8f@\xee]V\xb9\x1b\x8f6\x15'
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x1c
#      len       = 40
#      id        = 62318
#      flags     = DF
#      frag      = 0
#      ttl       = 124
#      proto     = tcp
#      chksum    = 0xf5d1
#      src       = 162.159.134.234
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = https
#         dport     = 49772
#         seq       = 1040526503
#         ack       = 1190622607
#         dataofs   = 5
#         reserved  = 0
#         flags     = A
#         window    = 12
#         chksum    = 0xaefa
#         urgptr    = 0
#         options   = []
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x1c
#      len       = 74
#      id        = 62319
#      flags     = DF
#      frag      = 0
#      ttl       = 124
#      proto     = tcp
#      chksum    = 0xf5ae
#      src       = 162.159.134.234
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = https
#         dport     = 49772
#         seq       = 1040526503
#         ack       = 1190622607
#         dataofs   = 5
#         reserved  = 0
#         flags     = PA
#         window    = 12
#         chksum    = 0xe86
#         urgptr    = 0
#         options   = []
# ###[ Raw ]###
#            load      = b'\x17\x03\x03\x00\x1d\x12\x1a\\\x0008s\xc7%tCV\xa1\xd5?\xb7\xf6V|B\x14~\x98u\xde\x82-\xe7\xbf'
#
# ###[ Ethernet ]###
#   dst       = 0a:c5:e1:a5:0f:65
#   src       = c4:9d:ed:1c:1d:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 40
#      id        = 22660
#      flags     = DF
#      frag      = 0
#      ttl       = 128
#      proto     = tcp
#      chksum    = 0x8cd8
#      src       = 192.168.43.65
#      dst       = 162.159.134.234
#      \options   \
# ###[ TCP ]###
#         sport     = 49772
#         dport     = https
#         seq       = 1190622607
#         ack       = 1040526537
#         dataofs   = 5
#         reserved  = 0
#         flags     = A
#         window    = 509
#         chksum    = 0xace7
#         urgptr    = 0
#         options   = []
#
# ###[ Ethernet ]###
#   dst       = 0a:c5:e1:a5:0f:65
#   src       = c4:9d:ed:1c:1d:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 41
#      id        = 38627
#      flags     = DF
#      frag      = 0
#      ttl       = 128
#      proto     = tcp
#      chksum    = 0xddb6
#      src       = 192.168.43.65
#      dst       = 20.107.133.224
#      \options   \
# ###[ TCP ]###
#         sport     = 49814
#         dport     = https
#         seq       = 1416465037
#         ack       = 3239966381
#         dataofs   = 5
#         reserved  = 0
#         flags     = A
#         window    = 512
#         chksum    = 0xcc86
#         urgptr    = 0
#         options   = []
# ###[ Raw ]###
#            load      = b'\x00'
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x1c
#      len       = 52
#      id        = 46776
#      flags     = DF
#      frag      = 0
#      ttl       = 43
#      proto     = tcp
#      chksum    = 0x12bb
#      src       = 20.107.133.224
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = https
#         dport     = 49814
#         seq       = 3239966381
#         ack       = 1416465038
#         dataofs   = 8
#         reserved  = 0
#         flags     = A
#         window    = 251
#         chksum    = 0xd97d
#         urgptr    = 0
#         options   = [('NOP', None), ('NOP', None), ('SAck', (1416465037, 1416465038))]
#
# ###[ Ethernet ]###
#   dst       = ff:ff:ff:ff:ff:ff
#   src       = c4:9d:ed:1c:1d:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 162
#      id        = 7522
#      flags     =
#      frag      = 0
#      ttl       = 128
#      proto     = udp
#      chksum    = 0x4458
#      src       = 192.168.43.65
#      dst       = 192.168.43.255
#      \options   \
# ###[ UDP ]###
#         sport     = 17500
#         dport     = 17500
#         len       = 142
#         chksum    = 0xd18e
# ###[ Raw ]###
#            load      = b'{"version": [2, 0], "port": 17500, "host_int": 235972922214784386697696647280230778317, "displayname": "", "namespaces": [3532357456]}'
#
# ###[ Ethernet ]###
#   dst       = 0a:c5:e1:a5:0f:65
#   src       = c4:9d:ed:1c:1d:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 40
#      id        = 34873
#      flags     = DF
#      frag      = 0
#      ttl       = 128
#      proto     = tcp
#      chksum    = 0xd7e
#      src       = 192.168.43.65
#      dst       = 104.208.16.95
#      \options   \
# ###[ TCP ]###
#         sport     = 50468
#         dport     = https
#         seq       = 166967507
#         ack       = 100879174
#         dataofs   = 5
#         reserved  = 0
#         flags     = RA
#         window    = 0
#         chksum    = 0x6fc8
#         urgptr    = 0
#         options   = []
#
# ###[ Ethernet ]###
#   dst       = 0a:c5:e1:a5:0f:65
#   src       = c4:9d:ed:1c:1d:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 41
#      id        = 40889
#      flags     = DF
#      frag      = 0
#      ttl       = 128
#      proto     = tcp
#      chksum    = 0x4bd2
#      src       = 192.168.43.65
#      dst       = 13.107.21.239
#      \options   \
# ###[ TCP ]###
#         sport     = 50471
#         dport     = https
#         seq       = 1188349147
#         ack       = 4155713960
#         dataofs   = 5
#         reserved  = 0
#         flags     = A
#         window    = 510
#         chksum    = 0xaaa3
#         urgptr    = 0
#         options   = []
# ###[ Raw ]###
#            load      = b'\x00'
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x1c
#      len       = 52
#      id        = 36889
#      flags     = DF
#      frag      = 0
#      ttl       = 113
#      proto     = tcp
#      chksum    = 0x6a4b
#      src       = 13.107.21.239
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = https
#         dport     = 50471
#         seq       = 4155713960
#         ack       = 1188349148
#         dataofs   = 8
#         reserved  = 0
#         flags     = A
#         window    = 16384
#         chksum    = 0x1f29
#         urgptr    = 0
#         options   = [('NOP', None), ('NOP', None), ('SAck', (1188349147, 1188349148))]
#
# ###[ Ethernet ]###
#   dst       = 0a:c5:e1:a5:0f:65
#   src       = c4:9d:ed:1c:1d:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 41
#      id        = 64005
#      flags     = DF
#      frag      = 0
#      ttl       = 128
#      proto     = tcp
#      chksum    = 0x37ab
#      src       = 192.168.43.65
#      dst       = 3.208.217.100
#      \options   \
# ###[ TCP ]###
#         sport     = 49903
#         dport     = https
#         seq       = 3344720008
#         ack       = 3973151062
#         dataofs   = 5
#         reserved  = 0
#         flags     = A
#         window    = 512
#         chksum    = 0x91fd
#         urgptr    = 0
#         options   = []
# ###[ Raw ]###
#            load      = b'\x00'
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x1c
#      len       = 52
#      id        = 22330
#      flags     = DF
#      frag      = 0
#      ttl       = 236
#      proto     = tcp
#      chksum    = 0x6e4f
#      src       = 3.208.217.100
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = https
#         dport     = 49903
#         seq       = 3973151062
#         ack       = 3344720009
#         dataofs   = 8
#         reserved  = 0
#         flags     = A
#         window    = 425
#         chksum    = 0xc72
#         urgptr    = 0
#         options   = [('NOP', None), ('NOP', None), ('SAck', (3344720008, 3344720009))]
#
# ###[ Ethernet ]###
#   dst       = 0a:c5:e1:a5:0f:65
#   src       = c4:9d:ed:1c:1d:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 201
#      id        = 40890
#      flags     = DF
#      frag      = 0
#      ttl       = 128
#      proto     = tcp
#      chksum    = 0x4b31
#      src       = 192.168.43.65
#      dst       = 13.107.21.239
#      \options   \
# ###[ TCP ]###
#         sport     = 50471
#         dport     = https
#         seq       = 1188349148
#         ack       = 4155713960
#         dataofs   = 5
#         reserved  = 0
#         flags     = PA
#         window    = 510
#         chksum    = 0x53d3
#         urgptr    = 0
#         options   = []
# ###[ Raw ]###
#            load      = b'\x17\x03\x03\x00\x9c\x00\x00\x00\x00\x00\x00\x00\x05\x85\xdd8\xdf\x85\x9f \xd4\xb5\x89\xf1\x05\x9f#\x05 D<;\r\'\xa9{\x8f\x81\xb0d\xac\xab\x9c\xedB4\x03\xb1\x80)\x0e\x8c\xc8@@\x1f7\x82\x82e\xe7\xa7\x83\nM\x95\x8fy\xff\xf0\xc4N\xd4\xbb$]\x93\xc8\xc9\x8e\x18L]P^=\x8d\xc1\xe0\xf7"\x97"\x9dd\x8ak\xd1*\xec\x82_K\xf4\xb3\xb0\x8f\xfb\x851ya34\xc0\xb2\x89\xa2\x9e"\xda(U\x98\x8f7Ua\xb1\x8cc\xa6\xafM\xca]\xb1r\xdc=\xc8\xb8s\x7f\x1d\xc9\x9b\x04g"2j\xf0\xd7\x80\xfem\x89\xf3R\xe0'
#
# ###[ Ethernet ]###
#   dst       = 0a:c5:e1:a5:0f:65
#   src       = c4:9d:ed:1c:1d:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 86
#      id        = 40891
#      flags     = DF
#      frag      = 0
#      ttl       = 128
#      proto     = tcp
#      chksum    = 0x4ba3
#      src       = 192.168.43.65
#      dst       = 13.107.21.239
#      \options   \
# ###[ TCP ]###
#         sport     = 50471
#         dport     = https
#         seq       = 1188349309
#         ack       = 4155713960
#         dataofs   = 5
#         reserved  = 0
#         flags     = PA
#         window    = 510
#         chksum    = 0x8e4a
#         urgptr    = 0
#         options   = []
# ###[ Raw ]###
#            load      = b"\x17\x03\x03\x00)\x00\x00\x00\x00\x00\x00\x00\x06\xa5kg\xd1\x8d%\x8c\x18+{\xdb\xfc\xeaf\x08\x1f(\x85.M}\xff\xa4r\xb2$zbz'\xd8ef"
#
# ###[ Ethernet ]###
#   dst       = 0a:c5:e1:a5:0f:65
#   src       = c4:9d:ed:1c:1d:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 1176
#      id        = 40892
#      flags     = DF
#      frag      = 0
#      ttl       = 128
#      proto     = tcp
#      chksum    = 0x4760
#      src       = 192.168.43.65
#      dst       = 13.107.21.239
#      \options   \
# ###[ TCP ]###
#         sport     = 50471
#         dport     = https
#         seq       = 1188349355
#         ack       = 4155713960
#         dataofs   = 5
#         reserved  = 0
#         flags     = PA
#         window    = 510
#         chksum    = 0xdc2a
#         urgptr    = 0
#         options   = []
# ###[ Raw ]###
#            load      = b'\x17\x03\x03\
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = https
#         dport     = 50471
#         seq       = 4155713960
#         ack       = 1188349355
#         dataofs   = 5
#         reserved  = 0
#         flags     = A
#         window    = 16383
#         chksum    = 0x6bd3
#         urgptr    = 0
#         options   = []
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x1c
#      len       = 86
#      id        = 36891
#      flags     = DF
#      frag      = 0
#      ttl       = 114
#      proto     = tcp
#      chksum    = 0x6927
#      src       = 13.107.21.239
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = https
#         dport     = 50471
#         seq       = 4155713960
#         ack       = 1188349355
#         dataofs   = 5
#         reserved  = 0
#         flags     = PA
#         window    = 16383
#         chksum    = 0xf3d0
#         urgptr    = 0
#         options   = []
# ###[ Raw ]###
#            load      = b'\x17\x03\x03\x00)\x00\x00\x00\x00\x00\x00\x00\x06\x86\x01\x01\xf1\xc1YO\x1d\xa9\xa8\xee\xdc\x87rM\xe7\xdeG\xb7][04\xc8u\x9b7#\x84O#9I'
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x1c
#      len       = 40
#      id        = 36892
#      flags     = DF
#      frag      = 0
#      ttl       = 114
#      proto     = tcp
#      chksum    = 0x6954
#      src       = 13.107.21.239
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = https
#         dport     = 50471
#         seq       = 4155714006
#         ack       = 1188350491
#         dataofs   = 5
#         reserved  = 0
#         flags     = A
#         window    = 16378
#         chksum    = 0x673a
#         urgptr    = 0
#         options   = []
#
# ###[ Ethernet ]###
#   dst       = 0a:c5:e1:a5:0f:65
#   src       = c4:9d:ed:1c:1d:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 40
#      id        = 40893
#      flags     = DF
#      frag      = 0
#      ttl       = 128
#      proto     = tcp
#      chksum    = 0x4bcf
#      src       = 192.168.43.65
#      dst       = 13.107.21.239
#      \options   \
# ###[ TCP ]###
#         sport     = 50471
#         dport     = https
#         seq       = 1188350491
#         ack       = 4155714006
#         dataofs   = 5
#         reserved  = 0
#         flags     = A
#         window    = 510
#         chksum    = 0xa536
#         urgptr    = 0
#         options   = []
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x1c
#      len       = 352
#      id        = 36893
#      flags     = DF
#      frag      = 0
#      ttl       = 114
#      proto     = tcp
#      chksum    = 0x681b
#      src       = 13.107.21.239
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = https
#         dport     = 50471
#         seq       = 4155714006
#         ack       = 1188350491
#         dataofs   = 5
#         reserved  = 0
#         flags     = PA
#         window    = 16378
#         chksum    = 0x2f5a
#         urgptr    = 0
#         options   = []
# ###[ Raw ]###
#            load      = b"\x17\x03\x03\x013\x00\x00\x00\x00\x00\x00\x00\x07U\x8b\xbf&In\xd9y\xe7\x03\x1bO\xe5\xfb\xd8\x83\xb9\x98\xd9\x9b;b\xe6i~\x84\x8f\x9a\xc7\xa08\xce5I\xe9[\xa4q\x7f7VI\x135\xbd\xbf\x14~\xe3\x1f\x8c\xf1R>i\x8a\xb1Br,\x00\xfd\x82\x94:\x14K\xa5\x08\x0cx\xcf#z \xf7\xfcUB[\xb4\xb1`\xf9\xce\xf3\x1d_3\xebv\xca\xd0K\x17\x83m\x8b\xa5\xe1s\x8a\xa8\xb0\xaf#\x07\xeeW&\xec>L\xdd\xce=\x7f\xedy\x17Q\x03\xd9\x19\xe9\xb8OY\xa3\xc4\xf7!\xdb\xf4,\x9aV\xdc\xfa\r\xba\xbd \xc0?\x0e\xb6\xe0\xdc\x01\x99\xbb\x83\xaa \x9e\x01h0\xe64\x0c\xc7\x9b\x05/[\x98\xb0\xd7\xd6\xcej\xca\x1c\xd4ZL\x01\x9a]\xb2\xfa\x9f\x010\xf9\x97\xcdu\xa6N\xf5]\xd0\x08\xbd7\xf9|~\xe6\xa1\x15$\xc8\xa9j{D1\x8f\xa4\x89\xf5\xf41$\xee\x02\x15c%\x7f\xe777a}\xf20\xab\xc9&W\x19{1\x1f\x0b\x1f\xcc\xe6\xfd\xb7t\xe3g\x92 0\xe3\xab\xb7\xc4'}\x80p\xcfO\xa9C]'\x18\xa3\x9e(\xf7\xde\xd3\x8e2\xc9)\xcdY\x0b\x07\x95\tq\xae\x1dM\xa5\xfd\xef@\xec\x8a\xb09V/e\r2"
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x1c
#      len       = 94
#      id        = 36894
#      flags     = DF
#      frag      = 0
#      ttl       = 114
#      proto     = tcp
#      chksum    = 0x691c
#      src       = 13.107.21.239
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = https
#         dport     = 50471
#         seq       = 4155714318
#         ack       = 1188350491
#         dataofs   = 5
#         reserved  = 0
#         flags     = PA
#         window    = 16378
#         chksum    = 0x6143
#         urgptr    = 0
#         options   = []
# ###[ Raw ]###
#            load      = b'\x17\x03\x03\x001\x00\x00\x00\x00\x00\x00\x00\x08o\xa1\xc6\xad\x95\xc1\x93vP\xc8\x13\xb8T\xb4\xe7$\xad,jDQ$\xd7\x7f\x9c\x88m\x88f$\xa6\xadB\xf3\xe4\xb3\xf0\x0c_#\xb0'
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x1c
#      len       = 170
#      id        = 36895
#      flags     = DF
#      frag      = 0
#      ttl       = 114
#      proto     = tcp
#      chksum    = 0x68cf
#      src       = 13.107.21.239
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = https
#         dport     = 50471
#         seq       = 4155714372
#         ack       = 1188350491
#         dataofs   = 5
#         reserved  = 0
#         flags     = PA
#         window    = 16378
#         chksum    = 0xaed5
#         urgptr    = 0
#         options   = []
# ###[ Raw ]###
#            load      = b"\x17\x03\x03\x00}\x00\x00\x00\x00\x00\x00\x00\ty/\n'&\x1e\x02uy\xf0eC?\x14,\x0b\x10 \x8b\x14\xb4#\x8aIU\xd6mlb[U\xc4\x9f'3\x91\xa7\xe8\x8dG\xbf\x1c\xa6\xa5\xfb\n\xbe\xe5*\xb1+\xc7\x12\xfc{\n\x1d\x18\xd44\xc5\x13\xf5M\x80Kn>\xb5\xecd\xb7\xach\xa8\xf6p?\xea\x7f\xec\xc0u\t.\x9e\x8f\xf3T*\xcf\xff\xc3Z\x93\xc9pwd\x16f\xb4\xd7/K\xca\x90NU\xbd\x9dW\xe3\xcbM\xa7\xfe"
#
# ###[ Ethernet ]###
#   dst       = 0a:c5:e1:a5:0f:65
#   src       = c4:9d:ed:1c:1d:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 40
#      id        = 40894
#      flags     = DF
#      frag      = 0
#      ttl       = 128
#      proto     = tcp
#      chksum    = 0x4bce
#      src       = 192.168.43.65
#      dst       = 13.107.21.239
#      \options   \
# ###[ TCP ]###
#         sport     = 50471
#         dport     = https
#         seq       = 1188350491
#         ack       = 4155714502
#         dataofs   = 5
#         reserved  = 0
#         flags     = A
#         window    = 514
#         chksum    = 0xa342
#         urgptr    = 0
#         options   = []
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x1c
#      len       = 78
#      id        = 36896
#      flags     = DF
#      frag      = 0
#      ttl       = 114
#      proto     = tcp
#      chksum    = 0x692a
#      src       = 13.107.21.239
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = https
#         dport     = 50471
#         seq       = 4155714502
#         ack       = 1188350491
#         dataofs   = 5
#         reserved  = 0
#         flags     = PA
#         window    = 16378
#         chksum    = 0x5316
#         urgptr    = 0
#         options   = []
# ###[ Raw ]###
#            load      = b'\x17\x03\x03\x00!\x00\x00\x00\x00\x00\x00\x00\n\xc5\xfc\xfe\xbc\x8a"\x88\xcdq\xa7\x89\xbc\x13\xe9+\x8a\xfb\xc6\xf6\x01\xd4\xd7r\xaa\xb7'
#
# ###[ Ethernet ]###
#   dst       = 0a:c5:e1:a5:0f:65
#   src       = c4:9d:ed:1c:1d:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 40
#      id        = 40895
#      flags     = DF
#      frag      = 0
#      ttl       = 128
#      proto     = tcp
#      chksum    = 0x4bcd
#      src       = 192.168.43.65
#      dst       = 13.107.21.239
#      \options   \
# ###[ TCP ]###
#         sport     = 50471
#         dport     = https
#         seq       = 1188350491
#         ack       = 4155714540
#         dataofs   = 5
#         reserved  = 0
#         flags     = A
#         window    = 513
#         chksum    = 0xa31d
#         urgptr    = 0
#         options   = []
#
# ###[ Ethernet ]###
#   dst       = 0a:c5:e1:a5:0f:65
#   src       = c4:9d:ed:1c:1d:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 82
#      id        = 40896
#      flags     = DF
#      frag      = 0
#      ttl       = 128
#      proto     = tcp
#      chksum    = 0x4ba2
#      src       = 192.168.43.65
#      dst       = 13.107.21.239
#      \options   \
# ###[ TCP ]###
#         sport     = 50471
#         dport     = https
#         seq       = 1188350491
#         ack       = 4155714540
#         dataofs   = 5
#         reserved  = 0
#         flags     = PA
#         window    = 513
#         chksum    = 0x88b7
#         urgptr    = 0
#         options   = []
# ###[ Raw ]###
#            load      = b'\x17\x03\x03\x00%\x00\x00\x00\x00\x00\x00\x00\x08\xfb`\xf6mJ\x89\xdf\x8c\x85\xcf1.\x00\xb9\x08\x7fm\xd8%\x04\x8e\xa4\x07`]\xe7}\xefP'
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x1c
#      len       = 40
#      id        = 36897
#      flags     = DF
#      frag      = 0
#      ttl       = 114
#      proto     = tcp
#      chksum    = 0x694f
#      src       = 13.107.21.239
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = https
#         dport     = 50471
#         seq       = 4155714540
#         ack       = 1188350533
#         dataofs   = 5
#         reserved  = 0
#         flags     = A
#         window    = 16384
#         chksum    = 0x64f4
#         urgptr    = 0
#         options   = []
#
# ###[ Ethernet ]###
#   dst       = 0a:c5:e1:a5:0f:65
#   src       = c4:9d:ed:1c:1d:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 41
#      id        = 44081
#      flags     = DF
#      frag      = 0
#      ttl       = 128
#      proto     = tcp
#      chksum    = 0x6648
#      src       = 192.168.43.65
#      dst       = 140.82.112.25
#      \options   \
# ###[ TCP ]###
#         sport     = 49950
#         dport     = https
#         seq       = 1082860083
#         ack       = 2746443301
#         dataofs   = 5
#         reserved  = 0
#         flags     = A
#         window    = 508
#         chksum    = 0x9411
#         urgptr    = 0
#         options   = []
# ###[ Raw ]###
#            load      = b'\x00'
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x1c
#      len       = 52
#      id        = 14417
#      flags     = DF
#      frag      = 0
#      ttl       = 42
#      proto     = tcp
#      chksum    = 0x3002
#      src       = 140.82.112.25
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = https
#         dport     = 49950
#         seq       = 2746443301
#         ack       = 1082860084
#         dataofs   = 8
#         reserved  = 0
#         flags     = A
#         window    = 78
#         chksum    = 0x9a2a
#         urgptr    = 0
#         options   = [('NOP', None), ('NOP', None), ('SAck', (1082860083, 1082860084))]
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x1c
#      len       = 158
#      id        = 21110
#      flags     = DF
#      frag      = 0
#      ttl       = 124
#      proto     = tcp
#      chksum    = 0x85e
#      src       = 162.125.21.3
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = https
#         dport     = 50418
#         seq       = 3182654931
#         ack       = 3268078481
#         dataofs   = 5
#         reserved  = 0
#         flags     = PA
#         window    = 248
#         chksum    = 0xf69e
#         urgptr    = 0
#         options   = []
# ###[ Raw ]###
#            load      = b"\x17\x03\x03\x00q\x00\x00\x00\x00\x00\x00\x00\x07I\xd1\xc9\xc2\x8d\x1cu\x8a\x0e\xe9\xcd\x1d@\x7ft\xba\xe7\x87\x01b\x9d\x17\xa0\xbf&:s\xba\xa8g\xc4%=\xed|3N\xc2}n\xdd9\xb9K\x08la\x86I\x03\xc9\xe6_d^\xbd\x8e\xfd1\xd2S\xe1h\x0b\xcd\xb4>\xde+\xe4\x85*h$\x8b\x1e|\xafv\xde\xed\xd7\x13\xe0\xdbn\xa50\xcb\x1d$\t\x82\x04\x00\x0bK\xfd'5*\x1a\xf5:\xed"
#
# ###[ Ethernet ]###
#   dst       = 0a:c5:e1:a5:0f:65
#   src       = c4:9d:ed:1c:1d:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 1093
#      id        = 64200
#      flags     = DF
#      frag      = 0
#      ttl       = 128
#      proto     = tcp
#      chksum    = 0x5880
#      src       = 192.168.43.65
#      dst       = 162.125.21.3
#      \options   \
# ###[ TCP ]###
#         sport     = 50418
#         dport     = https
#         seq       = 3268078481
#         ack       = 3182655049
#         dataofs   = 5
#         reserved  = 0
#         flags     = PA
#         window    = 510
#         chksum    = 0xa470
#         urgptr    = 0
#         options   = []
# ###[ Raw ]###
# ...
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x1c
#      len       = 40
#      id        = 4471
#      flags     = DF
#      frag      = 0
#      ttl       = 124
#      proto     = tcp
#      chksum    = 0x49d4
#      src       = 162.125.21.2
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = https
#         dport     = 50425
#         seq       = 1104815254
#         ack       = 474861972
#         dataofs   = 5
#         reserved  = 0
#         flags     = A
#         window    = 459
#         chksum    = 0xef99
#         urgptr    = 0
#         options   = []
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x1c
#      len       = 40
#      id        = 4472
#      flags     = DF
#      frag      = 0
#      ttl       = 124
#      proto     = tcp
#      chksum    = 0x49d3
#      src       = 162.125.21.2
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = https
#         dport     = 50425
#         seq       = 1104815254
#         ack       = 474863372
#         dataofs   = 5
#         reserved  = 0
#         flags     = A
#         window    = 464
#         chksum    = 0xea1c
#         urgptr    = 0
#         options   = []
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x1c
#      len       = 40
#      id        = 4473
#      flags     = DF
#      frag      = 0
#      ttl       = 124
#      proto     = tcp
#      chksum    = 0x49d2
#      src       = 162.125.21.2
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = https
#         dport     = 50425
#         seq       = 1104815254
#         ack       = 474864772
#         dataofs   = 5
#         reserved  = 0
#         flags     = A
#         window    = 469
#         chksum    = 0xe49f
#         urgptr    = 0
#         options   = []
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x1c
#      len       = 40
#      id        = 4474
#      flags     = DF
#      frag      = 0
#      ttl       = 124
#      proto     = tcp
#      chksum    = 0x49d1
#      src       = 162.125.21.2
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = https
#         dport     = 50425
#         seq       = 1104815254
#         ack       = 474866172
#         dataofs   = 5
#         reserved  = 0
#         flags     = A
#         window    = 475
#         chksum    = 0xdf21
#         urgptr    = 0
#         options   = []
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x1c
#      len       = 40
#      id        = 4475
#      flags     = DF
#      frag      = 0
#      ttl       = 124
#      proto     = tcp
#      chksum    = 0x49d0
#      src       = 162.125.21.2
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = https
#         dport     = 50425
#         seq       = 1104815254
#         ack       = 474867572
#         dataofs   = 5
#         reserved  = 0
#         flags     = A
#         window    = 480
#         chksum    = 0xd9a4
#         urgptr    = 0
#         options   = []
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x1c
#      len       = 40
#      id        = 4476
#      flags     = DF
#      frag      = 0
#      ttl       = 124
#      proto     = tcp
#      chksum    = 0x49cf
#      src       = 162.125.21.2
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = https
#         dport     = 50425
#         seq       = 1104815254
#         ack       = 474868972
#         dataofs   = 5
#         reserved  = 0
#         flags     = A
#         window    = 486
#         chksum    = 0xd426
#         urgptr    = 0
#         options   = []
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x1c
#      len       = 40
#      id        = 4477
#      flags     = DF
#      frag      = 0
#      ttl       = 124
#      proto     = tcp
#      chksum    = 0x49ce
#      src       = 162.125.21.2
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = https
#         dport     = 50425
#         seq       = 1104815254
#         ack       = 474870372
#         dataofs   = 5
#         reserved  = 0
#         flags     = A
#         window    = 491
#         chksum    = 0xcea9
#         urgptr    = 0
#         options   = []
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x1c
#      len       = 40
#      id        = 4478
#      flags     = DF
#      frag      = 0
#      ttl       = 124
#      proto     = tcp
#      chksum    = 0x49cd
#      src       = 162.125.21.2
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = https
#         dport     = 50425
#         seq       = 1104815254
#         ack       = 474871772
#         dataofs   = 5
#         reserved  = 0
#         flags     = A
#         window    = 497
#         chksum    = 0xc92b
#         urgptr    = 0
#         options   = []
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x1c
#      len       = 40
#      id        = 4479
#      flags     = DF
#      frag      = 0
#      ttl       = 124
#      proto     = tcp
#      chksum    = 0x49cc
#      src       = 162.125.21.2
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = https
#         dport     = 50425
#         seq       = 1104815254
#         ack       = 474872226
#         dataofs   = 5
#         reserved  = 0
#         flags     = A
#         window    = 502
#         chksum    = 0xc760
#         urgptr    = 0
#         options   = []
#
# ###[ Ethernet ]###
#   dst       = 0a:c5:e1:a5:0f:65
#   src       = c4:9d:ed:1c:1d:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 41
#      id        = 39210
#      flags     = DF
#      frag      = 0
#      ttl       = 128
#      proto     = tcp
#      chksum    = 0xe5c0
#      src       = 192.168.43.65
#      dst       = 23.214.120.36
#      \options   \
# ###[ TCP ]###
#         sport     = 50465
#         dport     = https
#         seq       = 4288577719
#         ack       = 1761232021
#         dataofs   = 5
#         reserved  = 0
#         flags     = A
#         window    = 512
#         chksum    = 0x3d2d
#         urgptr    = 0
#         options   = []
# ###[ Raw ]###
#            load      = b'\x00'
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x1c
#      len       = 1114
#      id        = 4480
#      flags     = DF
#      frag      = 0
#      ttl       = 124
#      proto     = tcp
#      chksum    = 0x4599
#      src       = 162.125.21.2
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = https
#         dport     = 50425
#         seq       = 1104815254
#         ack       = 474872226
#         dataofs   = 5
#         reserved  = 0
#         flags     = PA
#         window    = 502
#         chksum    = 0x72ca
#         urgptr    = 0
#         options   = []
# ###[ Raw ]###
#            load      = b'\x17\x03\x03\
#      flags     = DF
#      frag      = 0
#      ttl       = 128
#      proto     = tcp
#      chksum    = 0xfc60
#      src       = 192.168.43.65
#      dst       = 74.125.133.188
#      \options   \
# ###[ TCP ]###
#         sport     = 49876
#         dport     = 5228
#         seq       = 858375492
#         ack       = 4068047672
#         dataofs   = 5
#         reserved  = 0
#         flags     = A
#         window    = 514
#         chksum    = 0xb44d
#         urgptr    = 0
#         options   = []
# ###[ Raw ]###
#            load      = b'\x00'
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x1c
#      len       = 52
#      id        = 17836
#      flags     = DF
#      frag      = 0
#      ttl       = 124
#      proto     = tcp
#      chksum    = 0xfcd8
#      src       = 74.125.133.188
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = 5228
#         dport     = 49876
#         seq       = 4068047672
#         ack       = 858375493
#         dataofs   = 8
#         reserved  = 0
#         flags     = A
#         window    = 420
#         chksum    = 0x8db7
#         urgptr    = 0
#         options   = [('NOP', None), ('NOP', None), ('SAck', (858375492, 858375493))]
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x1c
#      len       = 81
#      id        = 14418
#      flags     = DF
#      frag      = 0
#      ttl       = 42
#      proto     = tcp
#      chksum    = 0x2fe4
#      src       = 140.82.112.25
#      dst       = 192.168.43.65
#      \options   \
# ###[ TCP ]###
#         sport     = https
#         dport     = 49950
#         seq       = 2746443301
#         ack       = 1082860084
#         dataofs   = 5
#         reserved  = 0
#         flags     = PA
#         window    = 78
#         chksum    = 0x2f19
#         urgptr    = 0
#         options   = []
# ###[ Raw ]###
#            load      = b"\x17\x03\x03\x00$2\xb8~\x07\xc2\xe2\xc3\x9de\xc8\x11\xd0c\x0c\x87lz\xcfnqd\xfas]\x81\xdd\xc5\x84\x19kL\x94B\x05'\xd7"
#
# ###[ Ethernet ]###
#   dst       = 0a:c5:e1:a5:0f:65
#   src       = c4:9d:ed:1c:1d:27
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 85
#      id        = 44082
#      flags     = DF
#      frag      = 0
#      ttl       = 128
#      proto     = tcp
#      chksum    = 0x661b
#      src       = 192.168.43.65
#      dst       = 140.82.112.25
#      \options   \
# ###[ TCP ]###
#         sport     = 49950
#         dport     = https
#         seq       = 1082860084
#         ack       = 2746443342
#         dataofs   = 5
#         reserved  = 0
#         flags     = PA
#         window    = 508
#         chksum    = 0x2379
#         urgptr    = 0
#         options   = []
# ###[ Raw ]###
#            load      = b'\x17\x03\x03\x00(^N\xe7\x9a\xf8Wa)(\xca#8-i\x03\xb2\x99\xc3\xb7\x93\xc9/\xff.pN\xd7\xa8\x8a\x17\x7f\xba(\x024\x06B\x80\x10\x9e'
#
# ###[ Ethernet ]###
#   dst       = c4:9d:ed:1c:1d:27
#   src       = 0a:c5:e1:a5:0f:65
#   type      = ARP
# ###[ ARP ]###
#      hwtype    = Ethernet (10Mb)
#      ptype     = IPv4
#      hwlen     = 6
#      plen      = 4
#      op        = who-has
#      hwsrc     = 0a:c5:e1:a5:0f:65
#      psrc      = 192.168.43.1
#      hwdst     = 00:00:00:00:00:00
#      pdst      = 192.168.43.65
# WARNING: Socket <scapy.arch.libpcap.L2pcapListenSocket object at 0x000001AD0ACB0510> failed with 'src'. It was closed.

# %%
# Convertir la liste en DataFrame après la capture
df = pd.DataFrame(captured_packets)

# Enregistrer les données dans un fichier CSV
df.to_csv('captured_packets.csv', index=False)
print("Données capturées enregistrées dans 'captured_packets.csv'")
# Out:
# Données capturées enregistrées dans 'captured_packets.csv'

# %%
# Charger les données à partir d'un fichier CSV
data = pd.read_csv("captured_packets.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   timestamp          84 non-null     float64
#  1   source             84 non-null     object
#  2   destination        84 non-null     object
#  3   protocol           84 non-null     int64
#  4   length             84 non-null     int64
#  5   normalized_length  84 non-null     float64
#  6   anomaly            84 non-null     int32
# dtypes: float64(2), int32(1), int64(2), object(2)
# memory usage: 4.4+ KB

# %%
data.head()
# Out:
#       timestamp          source     destination  protocol  length
# 0  1.733139e+09   192.168.43.65  74.125.133.188         6      55
# 1  1.733139e+09  74.125.133.188   192.168.43.65         6      66
# 2  1.733139e+09   192.168.43.65    2.16.162.236         6      54
# 3  1.733139e+09   192.168.43.65    2.16.162.236         6      54
# 4  1.733139e+09   192.168.43.65    2.16.162.236         6      54

# %%
# Nettoyer les données
data = data.dropna()  # Supprimer les valeurs manquantes

# %%
plt.figure(figsize=(8,5))
pd.crosstab(index=data["protocol"],columns=data["anomaly"].sort_values(ascending=False)).plot(kind='barh',stacked=True,figsize=(8,5))
# Out:
# <Axes: ylabel='protocol'>

# %% [markdown]
# ## Construction du modèle

# %%
# Normalisation des caractéristiques
data['normalized_length'] = (data['length'] - data['length'].mean()) / data['length'].std()

# %%
# Créer et entraîner le modèle
model = IsolationForest(contamination=0.1)  # Ajustez le taux de contamination
model.fit(data[['normalized_length']])
# Out:
# IsolationForest(contamination=0.1)

# %%
# Prédire les anomalies
data['anomaly'] = model.predict(data[['normalized_length']])

# %%
# -1 indique une anomalie, 1 indique un comportement normal
anomalies = data[data['anomaly'] == -1]
print("Anomalies détectées :")
print(anomalies)
# Out:
# Anomalies détectées :
#        timestamp         source    destination  protocol  length  \
# 36  1.733139e+09  192.168.43.65  13.107.21.239         6     215
# 38  1.733139e+09  192.168.43.65  13.107.21.239         6    1190
# 43  1.733139e+09  13.107.21.239  192.168.43.65         6     366
# 56  1.733139e+09  192.168.43.65   162.125.21.3         6     720
# 66  1.733139e+09  192.168.43.65   162.125.21.2         6     508
# 77  1.733139e+09   162.125.21.2  192.168.43.65         6    1128
#
#     normalized_length  anomaly
# 36          -0.086124       -1
# 38           2.141071       -1
# 43           0.258806       -1
# 56           1.067449       -1
# 66           0.583177       -1
# 77           1.999444       -1

# %%
anomalies_df = pd.DataFrame(anomalies)

# %%
anomalies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 36 to 77
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   timestamp          6 non-null      float64
#  1   source             6 non-null      object
#  2   destination        6 non-null      object
#  3   protocol           6 non-null      int64
#  4   length             6 non-null      int64
#  5   normalized_length  6 non-null      float64
#  6   anomaly            6 non-null      int32
# dtypes: float64(2), int32(1), int64(2), object(2)
# memory usage: 360.0+ bytes

# %%
anomalies_df.head()
# Out:
#        timestamp         source    destination  protocol  length  \
# 36  1.733139e+09  192.168.43.65  13.107.21.239         6     215
# 38  1.733139e+09  192.168.43.65  13.107.21.239         6    1190
# 43  1.733139e+09  13.107.21.239  192.168.43.65         6     366
# 56  1.733139e+09  192.168.43.65   162.125.21.3         6     720
# 66  1.733139e+09  192.168.43.65   162.125.21.2         6     508
#
#     normalized_length  anomaly
# 36          -0.086124       -1
# 38           2.141071       -1
# 43           0.258806       -1
# 56           1.067449       -1
# 66           0.583177       -1

# %%
plt.figure(figsize=(8,5))
plt.scatter(anomalies_df["length"],anomalies_df["anomaly"])
plt.xlabel('Longueur', fontsize=16)
plt.ylabel('Anomalie', fontsize=16)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 3
#       1 plt.figure(figsize=(8,5))
#       2 plt.scatter(anomalies_df["length"],anomalies_df["anomaly"])
# ----> 3 plt.xlabel('Longueur', frontsize=16)
#       4 plt.ylabel('Anomalie', frontsize=16)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:4150, in xlabel(xlabel, fontdict, labelpad, loc, **kwargs)
#    4141 @_copy_docstring_and_deprecators(Axes.set_xlabel)
#    4142 def xlabel(
#    4143     xlabel: str,
#    (...)
#    4148     **kwargs,
#    4149 ) -> Text:
# -> 4150     return gca().set_xlabel(
#    4151         xlabel, fontdict=fontdict, labelpad=labelpad, loc=loc, **kwargs
#    4152     )
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:3481, in _AxesBase.set_xlabel(self, xlabel, fontdict, labelpad, loc, **kwargs)
#    3474     x = {
#    3475         'left': 0,
#    3476         'center': 0.5,
#    3477         'right': 1,
#    3478     }[loc]
#    3479     kwargs.update(x=x, horizontalalignment=loc)
# -> 3481 return self.xaxis.set_label_text(xlabel, fontdict, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axis.py:1823, in Axis.set_label_text(self, label, fontdict, **kwargs)
#    1821 if fontdict is not None:
#    1822     self.label.update(fontdict)
# -> 1823 self.label.update(kwargs)
#    1824 self.stale = True
#    1825 return self.label
#
# File ~\anaconda3\Lib\site-packages\matplotlib\text.py:205, in Text.update(self, kwargs)
#     203 # Update bbox last, as it depends on font properties.
#     204 bbox = kwargs.pop("bbox", sentinel)
# --> 205 ret.extend(super().update(kwargs))
#     206 if bbox is not sentinel:
#     207     ret.append(self.set_bbox(bbox))
#
# File ~\anaconda3\Lib\site-packages\matplotlib\artist.py:1209, in Artist.update(self, props)
#    1201 def update(self, props):
#    1202     """
#    1203     Update this artist's properties from the dict *props*.
#    1204
#    (...)
#    1207     props : dict
#    1208     """
# -> 1209     return self._update_props(
#    1210         props, "{cls.__name__!r} object has no property {prop_name!r}")
#
# File ~\anaconda3\Lib\site-packages\matplotlib\artist.py:1193, in Artist._update_props(self, props, errfmt)
#    1191             func = getattr(self, f"set_{k}", None)
#    1192             if not callable(func):
# -> 1193                 raise AttributeError(
#    1194                     errfmt.format(cls=type(self), prop_name=k))
#    1195             ret.append(func(v))
#    1196 if ret:
#
# AttributeError: 'Text' object has no property 'frontsize'

# %%
plt.figure(figsize=(8,5))
pd.crosstab(index=anomalies_df["protocol"],columns=anomalies_df["anomaly"].sort_values(ascending=False)).plot(kind='barh',stacked=True,figsize=(8,5))
# Out:
# <Axes: ylabel='protocol'>

# %%
# Visualiser les anomalies
plt.figure(figsize=(10, 6))
plt.scatter(data['length'], data['anomaly'], c=data['anomaly'], cmap='coolwarm', alpha=0.5)
plt.title('Détection des anomalies de trafic réseau')
plt.xlabel('Longueur du paquet')
plt.ylabel('Anomalie')
plt.axhline(0, color='red', linestyle='--')  # Ligne de seuil
plt.grid()
plt.savefig("resultat-anomalie.png",dpi=200)
plt.show()

# %%
def alert_admin(anomalies):
    if not anomalies.empty:
        print("Alerte : Anomalies détectées !")
        # Ajouter ici des actions supplémentaires, comme envoyer un email.

# Alerter si des anomalies sont détectées
alert_admin(anomalies)
# Out:
# Alerte : Anomalies détectées !
